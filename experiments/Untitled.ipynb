# %%
pip install ellipsis matplotlib h3pandas
# Out:
# Requirement already satisfied: ellipsis in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (3.2.2)
# Requirement already satisfied: matplotlib in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (3.10.1)
# Collecting h3pandas
#   Downloading h3pandas-0.3.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: Fiona in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (1.10.1)
# Requirement already satisfied: Pillow in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (11.1.0)
# Requirement already satisfied: Shapely in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (2.0.7)
# Requirement already satisfied: dill in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (0.3.9)
# Requirement already satisfied: geopandas in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (1.0.1)
# Requirement already satisfied: geopy in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (2.4.1)
# Requirement already satisfied: imagecodecs in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (2025.3.30)
# Requirement already satisfied: imageio in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (2.37.0)
# Requirement already satisfied: numpy in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (2.2.4)
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (2.2.3)
# Requirement already satisfied: pygltflib in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (1.16.3)
# Requirement already satisfied: pyproj in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (3.7.1)
# Requirement already satisfied: rasterio in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (1.4.3)
# Requirement already satisfied: requests in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (2.32.3)
# Requirement already satisfied: requests-toolbelt in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (1.0.0)
# Requirement already satisfied: scikit-image in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (0.25.2)
# Requirement already satisfied: tifffile in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from ellipsis) (2025.3.30)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Collecting h3>=4 (from h3pandas)
#   Downloading h3-4.2.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: typing-extensions in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from h3pandas) (4.12.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from Fiona->ellipsis) (25.3.0)
# Requirement already satisfied: certifi in /opt/homebrew/opt/certifi/lib/python3.13/site-packages (from Fiona->ellipsis) (2025.1.31)
# Requirement already satisfied: click~=8.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from Fiona->ellipsis) (8.1.8)
# Requirement already satisfied: click-plugins>=1.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from Fiona->ellipsis) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from Fiona->ellipsis) (0.7.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from geopandas->ellipsis) (0.10.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from pandas->ellipsis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from pandas->ellipsis) (2025.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from geopy->ellipsis) (2.0)
# Requirement already satisfied: dataclasses-json>=0.0.25 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from pygltflib->ellipsis) (0.6.7)
# Requirement already satisfied: deprecated in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from pygltflib->ellipsis) (1.2.18)
# Requirement already satisfied: affine in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from rasterio->ellipsis) (2.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from requests->ellipsis) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from requests->ellipsis) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from requests->ellipsis) (2.3.0)
# Requirement already satisfied: scipy>=1.11.4 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from scikit-image->ellipsis) (1.15.2)
# Requirement already satisfied: networkx>=3.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from scikit-image->ellipsis) (3.4.2)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from scikit-image->ellipsis) (0.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from dataclasses-json>=0.0.25->pygltflib->ellipsis) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from dataclasses-json>=0.0.25->pygltflib->ellipsis) (0.9.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from deprecated->pygltflib->ellipsis) (1.17.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib->ellipsis) (1.0.0)
# Downloading h3pandas-0.3.0-py3-none-any.whl (53 kB)
# Downloading h3-4.2.2-cp313-cp313-macosx_11_0_arm64.whl (829 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.4/829.4 kB 6.0 MB/s eta 0:00:006.7 MB/s eta 0:00:01
# Installing collected packages: h3, h3pandas
# Successfully installed h3-4.2.2 h3pandas-0.3.0
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import ellipsis as el

pathId = '1a24a1ee-7f39-4d21-b149-88df5a3b633a'
timestampId = '45c47c8a-035e-429a-9ace-2dff1956e8d9'

sh_countries = el.path.vector.timestamp.listFeatures(pathId, timestampId)['result']

sh_usa = sh_countries[sh_countries['NAME'] == 'Belarus']
sh_usa.plot()
# Out:
# <Axes: >

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import h3pandas
#       2 resolution = 6
#       3 hexagons = sh_usa.h3.polyfill_resample(resolution)
#
# ModuleNotFoundError: No module named 'h3pandas'

# %%
import h3pandas
resolution = 5
hexagons = sh_usa.h3.polyfill_resample(resolution)
hexagons.plot()
# Out:
# <Axes: >
